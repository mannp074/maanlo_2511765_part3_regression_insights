# %%
# ==========================================
# model_equations.md
# ==========================================
with open("model_equations.md","w",encoding="utf-8") as f:

    f.write("# Model Equations\n\n")

    f.write("## Simple Regression Model 1\n\n")
    f.write("monthly_sales = β0 + β1(marketing_spend)\n\n")

    f.write("Higher marketing spend is associated with higher monthly sales.\n\n")

    f.write("## Simple Regression Model 2\n\n")
    f.write("monthly_sales = β0 + β1(footfall)\n\n")

    f.write("Higher customer footfall is associated with higher monthly sales.\n\n")

    f.write("## Multiple Regression Model\n\n")
    f.write("monthly_sales = β0 + β1(marketing_spend) + β2(footfall) + β3(inventory_availability_pct) + β4(customer_rating) + Dummy Variables\n\n")

    f.write("## Dummy Variables\n\n")
    f.write("- Region and store type were converted into dummy variables.\n")
    f.write("- One category was omitted and used as the reference category.\n")
    f.write("- This avoids the dummy variable trap.\n\n")

    f.write("## Final Model Selected\n\n")
    f.write("The multiple regression model was selected because it considers multiple business factors simultaneously and provides higher explanatory power than simple regression models.\n")


# ==========================================
# final_recommendation.md
# ==========================================
with open("final_recommendation.md","w",encoding="utf-8") as f:

    f.write("# Final Recommendation\n\n")

    f.write("## Key Factors Associated with Monthly Sales\n\n")
    f.write("- Marketing spend\n")
    f.write("- Footfall\n")
    f.write("- Inventory availability\n")
    f.write("- Customer ratings\n\n")

    f.write("## Management Focus\n\n")
    f.write("Leadership should focus on maintaining inventory levels, improving customer experience, and allocating marketing budgets efficiently.\n\n")

    f.write("## Variables That Should Not Be Over-Interpreted\n\n")
    f.write("Variables with weak statistical significance should be interpreted cautiously.\n\n")

    f.write("## Recommended Business Actions\n\n")
    f.write("- Increase effective marketing activities.\n")
    f.write("- Improve inventory availability.\n")
    f.write("- Enhance customer experience.\n")
    f.write("- Allocate resources to higher-performing store categories.\n\n")

    f.write("## Risks and Limitations\n\n")
    f.write("- Regression identifies association, not causation.\n")
    f.write("- External factors may affect sales.\n")
    f.write("- Some variations cannot be fully explained by the model.\n\n")

    f.write("## Why Correlation Does Not Imply Causation\n\n")
    f.write("Regression shows relationships between variables but cannot prove that one variable directly causes changes in sales.\n")


# ==========================================
# model_comparison.md
# ==========================================
with open("model_comparison.md","w",encoding="utf-8") as f:

    f.write("# Model Comparison\n\n")

    f.write("| Model | Variables Used | Business Usefulness |\n")
    f.write("|---------|--------------|-------------------|\n")
    f.write("| Simple Regression 1 | marketing_spend | Measures effect of marketing |\n")
    f.write("| Simple Regression 2 | footfall | Measures effect of customer traffic |\n")
    f.write("| Multiple Regression | Multiple predictors + dummy variables | Most useful for decision making |\n\n")

    f.write("## Limitations\n\n")
    f.write("- Models do not capture all external factors.\n")
    f.write("- Regression measures association rather than causation.\n")


# ==========================================
# README.md
# ==========================================
with open("README.md","w",encoding="utf-8") as f:

    f.write("# Regression-Based Business Insights & Model Interpretation\n\n")

    f.write("## Business Problem Summary\n\n")
    f.write("The objective is to identify factors associated with monthly sales across retail stores using regression analysis.\n\n")

    f.write("## Dataset Description\n\n")
    f.write("The dataset contains information related to store characteristics, marketing activities, customer behaviour, and sales performance.\n\n")

    f.write("## Dependent Variable\n\n")
    f.write("- monthly_sales\n\n")

    f.write("## Independent Variables\n\n")
    f.write("- marketing_spend\n")
    f.write("- footfall\n")
    f.write("- avg_discount_pct\n")
    f.write("- inventory_availability_pct\n")
    f.write("- customer_rating\n")
    f.write("- region\n")
    f.write("- store_type\n\n")

    f.write("## Regression Approach\n\n")
    f.write("Two simple regression models and one multiple regression model were developed.\n\n")

    f.write("## Dummy Variable Approach\n\n")
    f.write("Categorical variables were transformed using dummy variables while keeping one category as the reference category.\n\n")

    f.write("## Final Model Selected\n\n")
    f.write("Multiple regression model.\n\n")

    f.write("## Business Recommendation\n\n")
    f.write("Focus on marketing efficiency, inventory management, and customer satisfaction.\n\n")

    f.write("## Assumptions and Limitations\n\n")
    f.write("- Association does not imply causation.\n")
    f.write("- External factors may influence sales.\n\n")

    f.write("## Screenshots Included\n\n")
    f.write("- simple_regression_output.png\n")
    f.write("- multiple_regression_output.png\n")
    f.write("- residuals_preview.png\n")
    f.write("- model_comparison_preview.png\n")

print("All markdown files created successfully.")
# Out:
# All markdown files created successfully.
